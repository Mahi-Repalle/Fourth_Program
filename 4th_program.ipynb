# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('Child Labour in India.csv')

# %%
df
# Out:
#              Category of States            States  Agriculture Manufacturing  \
# 0   Non Special Category states    Andhra Pradesh         69.0           9.7
# 1   Non Special Category states             Assam         69.3           8.4
# 2   Non Special Category states             Bihar         71.8          11.2
# 3   Non Special Category states      Chhattisgarh         87.9           2.4
# 4   Non Special Category states             Delhi          0.0          11.1
# 5   Non Special Category states           Gujarat         76.7           2.6
# 6   Non Special Category states           Haryana         65.6           3.8
# 7   Non Special Category states         Jharkhand         65.3          14.6
# 8   Non Special Category states         Karnataka         82.6           9.3
# 9   Non Special Category states            Kerala         19.2          32.8
# 10  Non Special Category states    Madhya Pradesh         82.9          9. 9
# 11  Non Special Category states       Maharashtra         82.6           5.3
# 12  Non Special Category states            Orissa         73.2          17.4
# 13  Non Special Category states            Punjab         67.9          12.7
# 14  Non Special Category states         Rajasthan         75.8           9.6
# 15  Non Special Category states        Tamil Nadu         39.5          44.6
# 16  Non Special Category states     Uttar Pradesh         61.2          25.3
# 17  Non Special Category states       West Bengal         34.6          43.9
# 18      Special Category States  Himachal Pradesh         87.4             0
# 19      Special Category States       Uttarakhand         80.7           4.7
# 20                    All India         All India         68.1          16.6
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 1            1.8                         7.8
# 2            0.0                        15.5
# 3            0.9                         7.2
# 4            0.0                        57.8
# 5            0.3                        17.8
# 6            7.0                         8.1
# 7            4.3                        12.1
# 8            1.2                         5.7
# 9            0.0                        32.0
# 10           1.5                         4.3
# 11           1.9                         5.8
# 12           3.3                         3.3
# 13           1.2                         7.2
# 14           2.9                         7.3
# 15           5.9                         5.7
# 16           0.4                         9.7
# 17           3.3                         9.7
# 18           0.0                         6.7
# 19           5.2                         9.3
# 20           2.0                         8.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0    100
# 1                                      11.0     1.8    100
# 2                                       1.1     0.5    100
# 3                                       1.7     0.0    100
# 4                                      31.1     0.0    100
# 5                                       1.5     1.2    100
# 6                                      15.5     0.0    100
# 7                                       2.8     0.9    100
# 8                                       0.3     0.9    100
# 9                                      16.1     0.0    100
# 10                                      1.3     0.0    100
# 11                                      4.1     0.3    100
# 12                                      1.1     1.8    100
# 13                                      8.4     2.6    100
# 14                                      0.4     4.0    100
# 15                                      2.7     1.7    100
# 16                                      2.1     1.2    100
# 17                                      6.6     2.0    100
# 18                                      4.7     1.2    100
# 19                                      0.0     0.0    100
# 20                                      3.4     1.5    100

# %%
df['Category'] = df['Category of States'].replace(['Non Special Category states', 'Special Category States'],['Non Special', 'Special'])

# %%
df['Category']
# Out:
# 0     Non Special
# 1     Non Special
# 2     Non Special
# 3     Non Special
# 4     Non Special
# 5     Non Special
# 6     Non Special
# 7     Non Special
# 8     Non Special
# 9     Non Special
# 10    Non Special
# 11    Non Special
# 12    Non Special
# 13    Non Special
# 14    Non Special
# 15    Non Special
# 16    Non Special
# 17    Non Special
# 18        Special
# 19        Special
# 20      All India
# Name: Category, dtype: object

# %%
df['Category']=='Special'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# Name: Category, dtype: bool

# %%
df[df['Category']=='Special']
# Out:
#          Category of States            States  Agriculture Manufacturing  \
# 18  Special Category States  Himachal Pradesh         87.4             0
# 19  Special Category States       Uttarakhand         80.7           4.7
#
#     Construction  Trade Hotels & Restaurants  \
# 18           0.0                         6.7
# 19           5.2                         9.3
#
#     Community, Social and Personal Services  Others  Total Category
# 18                                      4.7     1.2    100  Special
# 19                                      0.0     0.0    100  Special

# %%
special=len(df[df['Category']=='Special'])

# %%
special
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 special
#
# NameError: name 'special' is not defined

# %%
#Percentage of Special and Non-Special and All india Category of State
special =len(df[df['Category'] == 'Special'])
non_special = len(df[df['Category']== 'Non Special'])
All_india=len(df[df['Category']== 'All India'])
sizes = [special, non_special,All_india]
labels = 'Special','Non Special','All_india'
colors = ['skyblue', 'yellowgreen','red']
explode = (0.2,0,0.3)
plt.pie(sizes, labels=labels,colors=colors,explode=explode,autopct='%1.1f%%', shadow=True)
plt.title('Percentage of Special and Non Special States and All india in the Dataset')
plt.axis('equal')
# Out:
# (-1.1148322823316803,
#  1.4114817048452613,
#  -1.099999937770302,
#  1.099999985577423)

# %%
#Distribution of child labour across various profession categories

sns.set_style('darkgrid')
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(16,8), sharey=True)
sns.distplot(df['Agriculture'], kde=False, bins=15,color='red', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][0])
sns.distplot(df['Manufacturing'], kde=False, bins=15,color='blue', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][1])
sns.distplot(df['Construction'], kde=False, bins=15,color='green', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][2])
sns.distplot(df['Trade Hotels & Restaurants'], kde=False, bins=15,color='purple', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][0])
sns.distplot(df['Community, Social and Personal Services'], kde=False, bins=15,color='aqua', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][1])
sns.distplot(df['Others'], kde=False, bins=15,color='gold', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][2])
plt.tight_layout()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\1924621822.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Agriculture'], kde=False, bins=15,color='red', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\1924621822.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Manufacturing'], kde=False, bins=15,color='blue', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][1])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 6
#       4 fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(16,8), sharey=True)
#       5 sns.distplot(df['Agriculture'], kde=False, bins=15,color='red', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][0])
# ----> 6 sns.distplot(df['Manufacturing'], kde=False, bins=15,color='blue', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][1])
#       7 sns.distplot(df['Construction'], kde=False, bins=15,color='green', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][2])
#       8 sns.distplot(df['Trade Hotels & Restaurants'], kde=False, bins=15,color='purple', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][0])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
#    2459 if a.ndim > 1:
#    2460     a = a.squeeze()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
#     891           dtype='datetime64[ns]')
#     892     """
# --> 893     return np.asarray(self._values, dtype)
#
# ValueError: could not convert string to float: '9. 9'

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                               object
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# Category                                    object
# dtype: object

# %%
df['Manufacturing'] =df['Manufacturing'].replace('9. 9', '9.9')
df['Manufacturing'] = df['Manufacturing'].astype('float')

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                              float64
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# Category                                    object
# dtype: object

# %%
#Distribution of child labour across various profession categories
sns.set_style('darkgrid')
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(16,8), sharey=True)
sns.distplot(df['Agriculture'], kde=False, bins=15,color='red', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][0])
sns.distplot(df['Manufacturing'], kde=False, bins=15,color='blue', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][1])
sns.distplot(df['Construction'], kde=False, bins=15,color='green', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][2])
sns.distplot(df['Trade Hotels & Restaurants'], kde=False, bins=15,color='purple', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][0])
sns.distplot(df['Community, Social and Personal Services'], kde=False, bins=15,color='aqua', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][1])
sns.distplot(df['Others'], kde=False, bins=15,color='gold', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][2])
plt.tight_layout()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\2109562363.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Agriculture'], kde=False, bins=15,color='red', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\2109562363.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Manufacturing'], kde=False, bins=15,color='blue', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][1])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\2109562363.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Construction'], kde=False, bins=15,color='green', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[0][2])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\2109562363.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Trade Hotels & Restaurants'], kde=False, bins=15,color='purple', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\2109562363.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Community, Social and Personal Services'], kde=False, bins=15,color='aqua', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][1])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34280\2109562363.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Others'], kde=False, bins=15,color='gold', hist_kws=dict(edgecolor="black", linewidth=2),ax=ax[1][2])

# %%
#Stacked Bar Chart of Child labourers employed across various states

fig,ax = plt.subplots(figsize=(17,8))
ax.bar(df['States'],df['Agriculture'],color='#70C1B3',label='Agriculture')
ax.bar(df['States'], df['Manufacturing'], bottom=df['Agriculture'], color='#247BA0', label='Manufacturing')
ax.bar(df['States'], df['Construction'], bottom=df['Agriculture']+df['Manufacturing'], color='#FFE066',label='Construction')
ax.bar(df['States'], df['Trade Hotels & Restaurants'], bottom=df['Agriculture']+df['Manufacturing']+df['Construction'], color='#F25F5C', label='Trade Hotels & Restaurants')
ax.bar(df['States'], df['Community, Social and Personal Services'], 
       bottom=df['Agriculture']+df['Manufacturing']+df['Construction'] + df['Trade Hotels & Restaurants'], color='#50514F', label='Community, Social and Personal Services')

ax.bar(df['States'], df['Others'], 
       bottom=df['Agriculture']+df['Manufacturing']+df['Construction'] + df['Trade Hotels & Restaurants']+df['Community, Social and Personal Services'],
       color='#A1CF6B', label='Others')

# ax.bar(df['States'],df['Other'])
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=3, mode="expand", borderaxespad=0.5)
plt.xticks(rotation=90)
plt.ylim((0, 110))
plt.show()
